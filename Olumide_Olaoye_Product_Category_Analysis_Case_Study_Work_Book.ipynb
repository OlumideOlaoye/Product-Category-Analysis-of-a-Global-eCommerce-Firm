# %% [markdown]
# # Product Category Analysis of a Global eCommerce Firm

# %% [markdown]
# ## Project Case Scenario
#
# Below is an analytical test you're to complete - you will find the dataset attached. While some questions have a correct answer, we are more interested in your line of thinking.
#
# ## Questions:
#
# 1.	What was the most profitable month for the company? (Assume constant commission rate across different categories.)
# 2.	What were the top 3 selling categories for the last quarter of 2015? How does it compare to the first quarter of the same year?
# 3.	Which product category has the highest average order value?
# 4.	Which regions experienced the biggest growth within the timeframe of the analysis?
# 5.	Which quarter has the highest cancellations? Why do you think that is the case?
# 6.	What are the main differences in shopping patterns across different genders?
# 7.	What products are more likely to be cancelled? What would you recommend to lower the cancellation rate?
# 8.	What are the top 5 categories the company should focus on?
# 9.	Which category has the best net/gross ratio. What do you think this means?
# 10.	If you had only enough marketing budget to send out only one newsletter (NL) to the buyers, how would you structure it (which products to focus, gender, location, etc.)? How would you track the NL success?
# 11.	Please draft an email summarizing trends you decipher from the dataset and the growth actions you would recommend (think in terms of partnerships, seller campaigns, online/offline strategies, etc.).
#
# ### Some terminology:
#
# •	Gross_transactions: when buyer places an order
#
# •	Net_transactions: when buyer receives the gross order
#
# •	Net/gross transaction value: the value of the order in euros.

# %% [markdown]
# ### Tasks:
#
# 1. Convert .xlsx file type to .csv file type to be able to use python packages for the analysis & visualization
#
# 2. Import appropriate libraries to use in cleaning and analyzing the dataset
#
# 3. Check if the data is clean or not
#
# 4. Explore the dataset
#
# 5. Analyze the dataset based on the questions asked by the stakeholders
#
# 6. Share your insights and recommendations with the stakeholders based on the questions asked

# %% [markdown]
# **Import the library packages**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
category_data = pd.read_csv('C:\\Users\\user\\Downloads\\Datasets\\Category Analyst (DATASET).csv')

# %%
## Display the first 5 rows in the table
category_data.head()
# Out:
#   Selling Region buyer_gender buyer_age_brackets     Product_category  \
# 0       region A       female        26-35 years                Books
# 1       region A       female        18-25 years                Books
# 2       region A       female        18-25 years         Boys Fashion
# 3       region A       female        18-25 years  Fitness & Nutrition
# 4       region A       female        18-25 years  Fitness & Nutrition
#
#      Month year_quarter  gross_transactions  gross_transaction_value(euros)  \
# 0  2015-03       2015Q1                   1                            2.84
# 1  2015-10       2015Q4                   1                           15.46
# 2  2015-05       2015Q2                   4                           14.10
# 3  2015-02       2015Q1                   1                           30.17
# 4  2015-03       2015Q1                   3                           34.48
#
#    net_transactions  net_transaction_value(euros)  canceled_transactons  \
# ...

# %%
## Dispaly the last 5 rows in the table
category_data.tail()
# Out:
#      Selling Region buyer_gender buyer_age_brackets         Product_category  \
# 9004      region AI         male          61+ years              Smartphones
# 9005      region AI         male        26-35 years              Smartphones
# 9006      region AI         male          61+ years              Smartphones
# 9007      region AJ         male          61+ years              Smartphones
# 9008      region AJ         male          61+ years  Vehicle & Vehicle Parts
#
#         Month year_quarter  gross_transactions  \
# 9004  2015-05       2015Q2                   1
# 9005  2015-07       2015Q3                   1
# 9006  2015-10       2015Q4                   1
# 9007  2015-01       2015Q1                   1
# 9008  2015-09       2015Q3                   2
#
#       gross_transaction_value(euros)  net_transactions  \
# 9004                           50.22                 0
# 9005                           49.46                 0
# ...

# %%
## Check for the numbers of rows and columns
category_data.shape
# Out:
# (9009, 12)

# %%
## Check for the data types of the variables
category_data.dtypes
# Out:
# Selling Region                        object
# buyer_gender                          object
# buyer_age_brackets                    object
# Product_category                      object
# Month                                 object
# year_quarter                          object
# gross_transactions                     int64
# gross_transaction_value(euros)       float64
# net_transactions                       int64
# net_transaction_value(euros)         float64
# canceled_transactons                   int64
# canceled_transactons_value(euros)    float64
# dtype: object

# %%
## More info about the dataset
category_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9009 entries, 0 to 9008
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Selling Region                     9009 non-null   object
#  1   buyer_gender                       9009 non-null   object
#  2   buyer_age_brackets                 9009 non-null   object
#  3   Product_category                   9009 non-null   object
#  4   Month                              9009 non-null   object
#  5   year_quarter                       9009 non-null   object
#  6   gross_transactions                 9009 non-null   int64
#  7   gross_transaction_value(euros)     9009 non-null   float64
#  8   net_transactions                   9009 non-null   int64
#  9   net_transaction_value(euros)       9009 non-null   float64
#  10  canceled_transactons               9009 non-null   int64
# ...

# %%
## Check if the data is clean or not by checking for null and duplicate values
category_data.isnull().sum()
# Out:
# Selling Region                       0
# buyer_gender                         0
# buyer_age_brackets                   0
# Product_category                     0
# Month                                0
# year_quarter                         0
# gross_transactions                   0
# gross_transaction_value(euros)       0
# net_transactions                     0
# net_transaction_value(euros)         0
# canceled_transactons                 0
# canceled_transactons_value(euros)    0
# dtype: int64

# %%
category_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# From the above, it shows the data is already cleaned

# %% [markdown]
# ### Question 1: What was the most profitable month for the company? (Assume constant commission rate across different categories.)

# %%
## To get the most profitable month, we check the relationship between the month and net_transaction_value(euros)
plt.figure(figsize=(15,10))
plt.title("Relationship between Month and Net Transaction Value (euros)")
plt.bar(category_data['Month'], category_data['net_transaction_value(euros)'])
# Out:
# <BarContainer object of 9009 artists>

# %% [markdown]
# From the barplot above, the most profitable month is **August 2015**.

# %% [markdown]
# ### Question 2: What were the top 3 selling categories for the last quarter of 2015? How does it compare to the first quarter of the same year?

# %%
## Productcategory (hue)
## year_quarter
## gross_transaction_value(euros)
plt.figure(figsize=(17,15))
plt.title("Comparison of the Quarters and Top Selling Categories")
sns.scatterplot(x='year_quarter', y='gross_transactions', data = category_data, hue = 'Product_category')
# Out:
# <AxesSubplot:title={'center':'Comparison of the Quarters and Top Selling Categories'}, xlabel='year_quarter', ylabel='gross_transactions'>

# %% [markdown]
# The top 3 selling categories for Q4 of 2015 are: **Women's Accessories, Men's Clothings, and Men's Shoes**
#
# In comparison with 2015, Q1 where the top 3 selling categories are: **Men's Clothings, Men's Shoes, and Men's Watches**

# %% [markdown]
# ### Question 3: Which product category has the highest average order value?

# %%
category_data.describe()
# Out:
#        gross_transactions  gross_transaction_value(euros)  net_transactions  \
# count         9009.000000                     9009.000000       9009.000000
# mean            48.698080                     2346.525608         16.623155
# std            299.248806                    16404.121183        120.670575
# min              1.000000                        0.000000          0.000000
# 25%              1.000000                       30.800000          0.000000
# 50%              4.000000                      117.100000          0.000000
# 75%             13.000000                      554.400000          2.000000
# max           6639.000000                   482974.740000       2685.000000
#
#        net_transaction_value(euros)  canceled_transactons  \
# count                   9009.000000           9009.000000
# mean                     438.806323             29.598735
# std                     2877.711876            169.085631
# ...

# %%
category_data['net_transaction_value(euros)'].mean()
# Out:
# 438.80632256632293

# %%
plt.figure(figsize=(17,15))
plt.title("Net Transaction Value (euros) vs Product Category")
sns.barplot(x='net_transaction_value(euros)', y='Product_category', data = category_data)
# Out:
# <AxesSubplot:title={'center':'Net Transaction Value (euros) vs Product Category'}, xlabel='net_transaction_value(euros)', ylabel='Product_category'>

# %% [markdown]
# The product category with the highest average order value is **'Men's Shoes'**

# %% [markdown]
# ### Question 4 : Which regions experienced the biggest growth within the timeframe of the analysis?

# %%
## Selling Region
## gross_transaction_value(euros)

category_data['Selling Region'].unique()
# Out:
# array(['region A', 'region B', 'region C', 'region D', 'region e',
#        'region F', 'region G', 'region H', 'region I', 'region J',
#        'region K', 'region L', 'region M', 'region N', 'region O',
#        'region P', 'region Q', 'region R', 'region S', 'region T',
#        'region U', 'region V', 'region W', 'region X', 'region Y',
#        'region Z', 'region AA', 'region AB', 'region AC', 'region AD',
#        'region AE', 'region AF', 'region AG', 'region AH', 'region AI',
#        'region AJ'], dtype=object)

# %%
plt.figure(figsize=(17, 15))
plt.title("Sales Growth By Region")
sns.barplot(x='gross_transaction_value(euros)', y='Selling Region', data=category_data)
# Out:
# <AxesSubplot:title={'center':'Sales Growth By Region'}, xlabel='gross_transaction_value(euros)', ylabel='Selling Region'>

# %% [markdown]
# **Region X** experienced the biggest growth within the timeframe of the analysis

# %% [markdown]
# ### Question 5: Which quarter has the highest cancellations? Why do you think that is the case?

# %%
## year_quarter
## canceled_transactons
plt.title("Cancellations By Quarters")
plt.bar(category_data['year_quarter'], category_data['canceled_transactons'])
# Out:
# <BarContainer object of 9009 artists>

# %% [markdown]
# **Quarter 1 of 2015** has the highest cancellations, which also resulted in lowest net transaction value because of highest cancellations. This might be largely due to high cancellation rate for the top selling categories during that quarter and changes in buyer behaviour for the product categories: Men's Clothing, Men's Shoes, and Men's Watches

# %% [markdown]
# ### Question 6: What are the main differences in shopping patterns across different genders?

# %%
## buyer_gender
## buyer_age_brackets
## net_transaction_value(euros)
plt.title("Buyer Age Brackets vs Net Transaction Value (euros)")
sns.barplot(x='buyer_age_brackets', y='net_transaction_value(euros)', data=category_data, hue='buyer_gender')
# Out:
# <AxesSubplot:title={'center':'Buyer Age Brackets vs Net Transaction Value (euros)'}, xlabel='buyer_age_brackets', ylabel='net_transaction_value(euros)'>

# %%
## Compare the relationships between buyer_gender, buyer_age_brackets and Product_category to determine the shopping pattern
plt.figure(figsize=(17,15))
plt.title("Relationships between Buyer Age Brackets, Product Category, with Buyer Gender")
sns.scatterplot(x='buyer_age_brackets', y='Product_category', data = category_data, hue='buyer_gender')
# Out:
# <AxesSubplot:title={'center':'Relationships between Buyer Age Brackets, Product Category, with Buyer Gender'}, xlabel='buyer_age_brackets', ylabel='Product_category'>

# %% [markdown]
# The main differences in shopping patterns across different genders are in the buyers age brackets and also preference for particular product categories. The male gender spends more money on shopping than the female gender across the different age brackets apart from 18-25 years where females spend is closely matched by males spend. This could be due to the fact that most men go shopping for their wives and girlfriends more often than females go shopping for themselves or for their men. The shopping patterns are more obvious for age bracket 36-45 years where we have more shopping activities with the male gender shopping more than the female gender. Some product caterories are missing out in age brackets 18-25 years, 26-35 years, 46-51 years and 61+ years. Almost all the product categories are showing in the 36-45 years age bracket.

# %% [markdown]
# ### Question 7: What products are more likely to be cancelled? What would you recommend to lower the cancellation rate?

# %%
## Product_category
## canceled_transactons
plt.figure(figsize=(17,15))
plt.title("Product Category vs Cancelled Transactions")
sns.barplot(x='canceled_transactons', y='Product_category', data=category_data)
# Out:
# <AxesSubplot:title={'center':'Product Category vs Cancelled Transactions'}, xlabel='canceled_transactons', ylabel='Product_category'>

# %% [markdown]
# The top 5 products that are more likely to be cancelled are: **Men's Clothing, Men's Shoes, Women's Clothing, Smartphones, and Women's Shoes.**
#
# To lower the cancellation rate, it is recommended that the steps from add to cart and payment be shortened in order to discourage buyers from cancellation of orders.

# %% [markdown]
# ### Question 8: What are the top 5 categories the company should focus on?

# %%
category_data['Product_category'].unique()
# Out:
# array(['Books', 'Boys Fashion', 'Fitness & Nutrition', 'Furniture',
#        'Girls Fashion', 'Girls Shoes', 'Headphones',
#        'Household Appliances', 'Kitchen & Dining', 'Laptops',
#        "Men's Clothing", "Men's Shoes", "Men's Watches",
#        'MP3 Players and Audio Equipment', 'Nursing & Feeding',
#        'Other Baby Products', 'PowerBanks', 'Skin Care', 'Smartphones',
#        'Team Sports', 'TVs', "Women's Accessories", "Women's Clothing",
#        "Women's Jewelry", "Women's Shoes", "Women's Watches", 'Cameras',
#        "Men's Accessories", 'Mobiles & Tablets Accessories', 'Services',
#        'Storage Devices', 'Vehicle & Vehicle Parts', 'Video Games',
#        'Baby & Toddler Furniture', 'Baby Shoes', 'Bath & Body',
#        'Bathroom Accessories', 'Beverages', 'Boys Shoes', 'Candies',
#        'Computer Accessories', 'Decor', 'Desktops', 'Diapering',
#        'Gymnastics', 'Health Care', 'Home improvements',
# ...

# %%
category_data.Product_category.value_counts()
# Out:
# Smartphones                405
# Women's Clothing           316
# Women's Shoes              296
# Men's Shoes                274
# Women's Watches            265
#                           ...
# Religious & Ceremonial       1
# Gadgets                      1
# Hobbies & Creative Arts      1
# Ticketing                    1
# Water Sports                 1
# Name: Product_category, Length: 97, dtype: int64

# %%
plt.figure(figsize=(25,10))
plt.title("Counts of Product Category")
sns.countplot('Product_category', data=category_data, palette='deep')
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# The top 5 categories the company should focus on are: **Smartphones, Women's Clothing, Women's Shoes, Men's Shoes, and Women's Watches**

# %% [markdown]
# ### Question 9: Which category has the best net/gross ratio. What do you think this means?

# %%
category_data.head()
# Out:
#   Selling Region buyer_gender buyer_age_brackets     Product_category  \
# 0       region A       female        26-35 years                Books
# 1       region A       female        18-25 years                Books
# 2       region A       female        18-25 years         Boys Fashion
# 3       region A       female        18-25 years  Fitness & Nutrition
# 4       region A       female        18-25 years  Fitness & Nutrition
#
#      Month year_quarter  gross_transactions  gross_transaction_value(euros)  \
# 0  2015-03       2015Q1                   1                            2.84
# 1  2015-10       2015Q4                   1                           15.46
# 2  2015-05       2015Q2                   4                           14.10
# 3  2015-02       2015Q1                   1                           30.17
# 4  2015-03       2015Q1                   3                           34.48
#
#    net_transactions  net_transaction_value(euros)  canceled_transactons  \
# ...

# %%
## Create a new column 'net/gross ratio' which is 'net_trasaction_value(euros) / gross_transaction_value(euros)'
category_data['net/gross ratio'] = category_data['net_transaction_value(euros)'] / category_data['gross_transaction_value(euros)']

# %%
category_data.head(5)
# Out:
#   Selling Region buyer_gender buyer_age_brackets     Product_category  \
# 0       region A       female        26-35 years                Books
# 1       region A       female        18-25 years                Books
# 2       region A       female        18-25 years         Boys Fashion
# 3       region A       female        18-25 years  Fitness & Nutrition
# 4       region A       female        18-25 years  Fitness & Nutrition
#
#      Month year_quarter  gross_transactions  gross_transaction_value(euros)  \
# 0  2015-03       2015Q1                   1                            2.84
# 1  2015-10       2015Q4                   1                           15.46
# 2  2015-05       2015Q2                   4                           14.10
# 3  2015-02       2015Q1                   1                           30.17
# 4  2015-03       2015Q1                   3                           34.48
#
#    net_transactions  net_transaction_value(euros)  canceled_transactons  \
# ...

# %%
## To get the category with the best net/gross ratio
plt.figure(figsize=(17,15))
plt.title("Product Category vs Net/Gross Ratio")
sns.barplot(x='net/gross ratio', y='Product_category', data=category_data)
# Out:
# <AxesSubplot:title={'center':'Product Category vs Net/Gross Ratio'}, xlabel='net/gross ratio', ylabel='Product_category'>

# %% [markdown]
# **Jewelry Cleaning & Care** and **Gadgets** have the highest net/gross ratio among the product categories.
#
# What this means is that the cost incurred on the sales and delivery of Jewelry Cleaning & Care and Gadgets are small compared to other product categories.

# %% [markdown]
# ### Question 10: If you had only enough marketing budget to send out only one newsletter (NL) to the buyers, how would you structure it (which products to focus, gender, location, etc.)? How would you track the NL success?

# %% [markdown]
# Based on the above analyses carried out on the dataset, to manage the limited marketing budget, I would send out one newsletter to the buyers that are **males**, at the **region or location X**, and with a focus on the following products: **Smartphones, Women's Clothing, Women's Shoes, Men's Shoes, and Women's Watches**. It seems that men in region X are spending more money on ordering smartphones (for their wives/girlfriends and themselves), women's shoes, women's watches, and women's clothing (for their wives and girlfriends), and men's shoes (for themselves), compared to other regions.
#
# I would track for the NL success by checking the sales performance among the product categories, compare sales performance based on gender and also track the sales performance in region X compared to other regions. I will also track the NL success by comparing sales performance of those I sent NL to and those I did not send the NL to.

# %% [markdown]
# ### Question 11: Please draft an email summarizing trends you decipher from the dataset and the growth actions you would recommend (think in terms of partnerships, seller campaigns, online/offline strategies, etc.).

# %% [markdown]
# **Email summarizing trends and growth actions recommended**
#
# **From: olumide.olaoye1@gmail.com**
#
# **To: The Stakeholders (email address)**
#
# **SUBJECT: Product Category Analysis - Trends and Growth Actions Recommendations**
#
# Dear All,
#
# Trust this mail meets you well.
#
# Once again, thank you for the opportunity to work on this project.
#
# Please find below the trends identified after conducting analyses on the datasets:
#
# 1. The level of profitability for the company was lowest in Q1 and highest in Q4 with August being the most profitable month for the year 2015.
#
# 2. Men's Clothing topped the chat for the highest selling categories for Q1 and Q2, while Women's Accessories topped the chat for highest selling cateories for Q3 and Q4. This shows that generally Fashion items are top of the selling categories all through the year.
#
# 3. Buyers ordered more for Men's Shoes which translated into highest amount of net transaction value in Euros.
#
# 4. The region with the biggest growth within the year under analysis (2015) was region X, with the highest gross transaction value coming from that region.
#
# 5. Q1 of 2015 has the highest rate of cancellations, which also resulted in lowest net transaction value because of highest cancellations. This might be largely due to high cancellation rate for the top selling categories during that quarter and changes in buyer behaviour for the product categories: Men's Clothing, Men's Shoes, and Men's Watches.
#
# 6. The main differences in shopping patterns across different genders are in the buyers age brackets and also preference for particular product categories. The male gender spends more money on shopping than the female gender across the different age brackets apart from 18-25 years where females spend more than males. The shopping patterns are more obvious for age bracket 36-45 years where we have more shopping activities with the male gender shopping more than the female gender. Some product caterories are missing out in age brackets 18-25 years, 26-35 years, 46-51 years and 61+ years. Almost all the product categories are showing in the 36-45 years age bracket.
#
# 7. The top 5 products that are more likely to be cancelled are: Men's Clothing, Men's Shoes, Women's Clothing, Smartphones, and Women's Shoes.
#
# 8. Jewelry Cleaning & Care and Gadgets have the highest net/gross ratio among the product categories.
#
# Based on the above trends identified from the analysis, the following are growth actions recommended to the stakeholders to achieve the business objective of maximizing profits:
#
# 1. It is very likely that Black Friday Sales campaign held in the month of August which resulted in highest profitability in that month. Hence, I recommend the company introduces similar seller campaigns for every quarter to enhance profitability all through the year.
#
# 2. To lower the cancellation rate acrosss all product categories, it is recommended that the process of ordering and payment on the platform be swift and more user-friendly. This will reduce order cancelllation rate and increase sales.
#
# 3. It is highly recommended that the company recruits more vendors/partners in the regions and product categories where activities are slow and low orders/sales are noticed. This will replicate the high growth performance as recorded for region X in the analysis.
#
# 4. To enhance profitability among the top selling product categories, it is recommended that cost of logistics and delivery should be minimise in order to increase the net/gross ratio among these top selling categories.
#
# 5. The company should create campaigns and online/offline promotional offers to encourage and capture younger generations (18-25 years age bracket) in order to increase ordering and buying activities among these age bracket across all regions.
#
# 6. Lastly, I recommend launch of discounted sales offer for product categories that recorded low gross transaction values and in regions where growth profitability are low.
#
# Regards,
#
# Olumide Olaoye
